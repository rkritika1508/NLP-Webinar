# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#       speaker                                         transcript
# 855    tyrion   your grace i know my brother he came here alo...
# 117    cersei   your mother might have prepared you you flowe...
# 341     jaime   she did she lied to me as well she never had ...
# 156  daenerys   who stabbed him in the back and cut his throa...
# 358       jon   we need every man we can get i thought wed lo...
# 746     sansa   youre right we cant trust him he attacked my ...
# 176     davos   you are now look i made it through most of my...
# 884     varys   oh lord tyrion come in come in oh always in c...
# 29       arya   you make my weapon yet you should make mine f...
# 866     tywin   wolfsbane a rare substance this is no common ...
# 833     theon   my queen she only has a few ships and she cou...
# 736       sam   im sorry hes beautiful hes beautiful  does he...
# 90      bronn   to the boys drunk lannisters thank you very m...
# 86    brienne   you dont know me well your grace but i know s...
# 617    olenna    there appears to be a good deal of room else...

# %%
# Extract only text by Varys
varys_text = data.transcript.loc[884]
varys_text[:200]
# Out:
# ' oh lord tyrion come in come in oh always in confidence oh no its a wonderful time end your life proof will there be a trial i have no proof only whispers before all this nastiness i was going to tell'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Varys' routine, take a look at it
varys_dict = markov_chain(varys_text)
varys_dict
# Out:
# {'': ['oh',
#   'not',
#   'thats',
#   'i',
#   'i',
#   'its',
#   'as',
#   'when',
#   'and',
#   'you',
#   'jon',
#   'its',
#   'nothing',
#   'the',
#   'presumably',
#   '',
#   'anything',
#   'fair',
#   'how',
#   'flies',
#   'hammers',
#   'tears',
#   'we',
#   'a',
#   'dom',
#   'she',
#   'it',
#   'and',
#   'go',
#   'i',
#   'i',
#   'shes',
#   'cersei',
#   'ive',
#   'silver',
#   'strong',
#   'not',
#   'nothing',
#   'at',
#   'and',
#   'serve',
#   'welcome',
#   'my',
#   'i',
#   'you',
#   'dont',
#   'strange',
#   'you',
#   'i',
#   'oh',
#   'give',
#   'nothing',
#   'why',
#   'so',
#   'good',
#   'if',
#   'im',
#   'my',
#   '',
#   'our',
#   'two',
#   'the',
#   'ellaria',
#   'the',
#   'your',
#   'to',
#   '',
#   'the',
#   'a',
#   'they',
#   'i',
#   'the'],
#  'oh': ['lord', 'always', 'no', 'i', 'no', 'i', 'you'],
#  'lord': ['tyrion',
#   'tyrions',
#   'stark',
#   'for',
#   'i',
#   'stannis',
#   'of',
#   'of',
#   'why',
#   'my',
#   'daenerys',
#   'hand',
#   'you',
#   'he',
#   'i',
#   'tyrion',
#   'we',
#   'i',
#   'who',
#   'we',
#   'tyrion',
#   'hand',
#   'i',
#   'but',
#   'not',
#   'of',
#   'you',
#   'and',
#   'baelish',
#   'we',
#   'robb',
#   'hoster',
#   'of',
#   'but',
#   'hand',
#   'are'],
#  'tyrion': ['come', 'lannister', 'to', 'to'],
#  'come': ['in',
#   'in',
#   'to',
#   'back',
#   'in',
#   'but',
#   'and',
#   'my',
#   'back',
#   'you',
#   'along'],
#  'in': ['come',
#   'oh',
#   'confidence',
#   'myr',
#   'a',
#   'your',
#   'time',
#   'lord',
#   'the',
#   'poor',
#   'your',
#   'odd',
#   'sansa',
#   'the',
#   'her',
#   'westeros',
#   'the',
#   'what',
#   'what',
#   'service',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'westeros',
#   'the',
#   'the',
#   'no',
#   'a',
#   'to',
#   'volantis',
#   'kings',
#   'you',
#   'history',
#   'being',
#   'alleys',
#   'the',
#   'and',
#   'the',
#   'the',
#   'the',
#   'the',
#   'our',
#   'other',
#   'kings',
#   'her',
#   'winterfell',
#   'the',
#   'the',
#   'the',
#   'their',
#   'the',
#   'meereen',
#   'essos',
#   'girls',
#   'it',
#   'my',
#   'a',
#   'half',
#   'his',
#   'the',
#   'your',
#   'the',
#   'his',
#   'thievery',
#   'all',
#   'the',
#   'the',
#   'the',
#   'valyrian',
#   'the',
#   'gold',
#   'that',
#   'saviors',
#   'the',
#   'the',
#   'riverrun',
#   'starks',
#   'practice',
#   'name',
#   'lady',
#   'a'],
#  'always': ['in', 'hated', 'trust', 'right', 'struggled', 'known'],
#  'confidence': ['oh'],
#  'no': ['its',
#   'proof',
#   'doubt',
#   'lands',
#   'wealth',
#   'armies',
#   'i',
#   'name',
#   'immediate',
#   'interest',
#   'better',
#   'matter',
#   'and',
#   'its',
#   'but',
#   'matter',
#   'longer',
#   'one',
#   'part',
#   'i',
#   'pet',
#   'legendary',
#   'one',
#   'man',
#   'one',
#   'i',
#   'other',
#   'you',
#   'need'],
#  'its': ['a',
#   'tendrils',
#   'been',
#   'what',
#   'a',
#   'a',
#   'just',
#   'true',
#   'breath',
#   'not',
#   'information',
#   'worse',
#   'actually',
#   'a',
#   'queen',
#   'a',
#   'done',
#   'only',
#   'swordsmen',
#   'a'],
#  'a': ['wonderful',
#   'trial',
#   'boy',
#   'troupe',
#   'certain',
#   'potion',
#   'hooked',
#   'brazier',
#   'voice',
#   'god',
#   'demon',
#   'conjurers',
#   'voice',
#   'symbolic',
#   'matter',
#   'mans',
#   'weed',
#   'long',
#   'bit',
#   'woman',
#   'featherbed',
#   'little',
#   'babe',
#   'lovely',
#   'confidant',
#   'shame',
#   'man',
#   'low',
#   'lovely',
#   'possible',
#   'dead',
#   'city',
#   'siege',
#   'red',
#   'man',
#   'purveyor',
#   'way',
#   'sealed',
#   'large',
#   'hundredfold',
#   'perfectly',
#   'child',
#   'good',
#   'night',
#   'sweet',
#   'foreign',
#   'house',
#   'very',
#   'new',
#   'good',
#   'better',
#   'complication',
#   'true',
#   'grand',
#   'massive',
#   'pact',
#   'straight',
#   'secret',
#   'sweat',
#   'torturer',
#   'lot',
#   'cause',
#   'different',
#   'handsome',
#   'problem',
#   'third',
#   'ship',
#   'woman',
#   'bag',
#   'new',
#   'choice',
#   'great',
#   'slave',
#   'child',
#   'targaryen',
#   'coin',
#   'thousand',
#   'certain',
#   'gaping',
#   'fragile',
#   'good',
#   'man',
#   'glorious',
#   'fanatic',
#   'mistake',
#   'fanatic',
#   'lordship',
#   'ruler',
#   'man',
#   'secret',
#   'handful',
#   'war',
#   'mistake',
#   'mistake',
#   'solution',
#   'better',
#   'man',
#   'man',
#   'lot',
#   'targaryen',
#   'stark',
#   'mistake',
#   'choice',
#   'generous',
#   'company',
#   'bit',
#   'child',
#   'powerful',
#   'nobleman',
#   'long',
#   'thing',
#   'matter',
#   'crypt',
#   'terrible',
#   'council',
#   'man',
#   'dead',
#   'long',
#   'marked',
#   'better',
#   'most',
#   'fertility',
#   'song',
#   'cliff',
#   'bashful',
#   'good',
#   'difficult',
#   'rich',
#   'boy',
#   'dragon',
#   'merchant',
#   'group',
#   'coward',
#   'dangerous',
#   'role',
#   'bit',
#   'land',
#   'monarch',
#   'ruler',
#   'powerful',
#   'choice',
#   'couch',
#   'glass',
#   'collection',
#   'potential',
#   'dangerous',
#   'dead',
#   'ward',
#   'black',
#   'curious',
#   'room',
#   'king',
#   'priest',
#   'rich',
#   'common',
#   'trick',
#   'shadow',
#   'very',
#   'very',
#   'distance'],
#  'wonderful': ['time'],
#  'time': ['end',
#   'i',
#   'if',
#   'then',
#   'i',
#   'a',
#   'at',
#   'for',
#   'in',
#   'before',
#   'my'],
#  'end': ['your', 'well'],
#  'your': ['life',
#   'fight',
#   'profession',
#   'presence',
#   'time',
#   'grace',
#   'grace',
#   'aunt',
#   'presence',
#   'home',
#   'enemies’',
#   'friends',
#   'friends',
#   'beard',
#   'throat',
#   'name',
#   'body',
#   'perspective',
#   'boy',
#   'perspective',
#   'arrival',
#   'graceserve',
#   'father',
#   'marriage',
#   'grace',
#   'existence',
#   'advantage',
#   'grace',
#   'wishes',
#   'dragons',
#   'empathy',
#   'second',
#   'priestesses',
#   'head',
#   'brief',
#   'aunt',
#   'grace',
#   'grace',
#   'grace',
#   'sister',
#   'father',
#   'father',
#   'father',
#   'father',
#   'face',
#   'father',
#   'bravery',
#   'fathers',
#   'new',
#   'father',
#   'presence',
#   'father',
#   'grace',
#   'personal',
#   'life',
#   'shit',
#   'brother',
#   'father’s',
#   'true',
#   'current',
#   'current',
#   'sisters',
#   'squires',
#   'friend',
#   'father',
#   'sister',
#   'father'],
#  'life': ['proof',
#   'with',
#   'a',
#   'far',
#   'for',
#   'they',
#   'has',
#   'unfortunate',
#   'if'],
#  'proof': ['will', 'only'],
#  'will': ['there',
#   'be',
#   'the',
#   'be',
#   'be',
#   'he',
#   'never',
#   'try',
#   'poor',
#   'serve',
#   'dedicate',
#   'and',
#   'never',
#   'know',
#   'die',
#   'as',
#   'never',
#   'die',
#   'act',
#   'not',
#   'leave',
#   'be',
#   'you',
#   'be',
#   'not'],
#  'there': ['be',
#   'is',
#   'have',
#   'has',
#   'will',
#   'to',
#   'soon',
#   'are',
#   'and',
#   'was',
#   'are'],
#  'be': ['a',
#   'yours',
#   'bringing',
#   'king',
#   'with',
#   'useless',
#   'their',
#   'your',
#   'fickle',
#   'sure',
#   'beautiful',
#   'done',
#   'rewarded',
#   'missing',
#   'double',
#   'careful',
#   'destroyed',
#   'someone',
#   'able',
#   'fully',
#   'disappointed',
#   'in',
#   'years',
#   'nowhere',
#   'safe',
#   'there',
#   'saved',
#   'you',
#   'hes',
#   'a',
#   'seeing',
#   'pleased',
#   'worried'],
#  'trial': ['i'],
#  'i': ['have',
#   'was',
#   'was',
#   'traveled',
#   'feared',
#   'heard',
#   'still',
#   'dream',
#   'dont',
#   'have',
#   'was',
#   'have',
#   'had',
#   'resolved',
#   'begged',
#   'sold',
#   'became',
#   'made',
#   'tended',
#   'managed',
#   'have',
#   'wanted',
#   'sit',
#   'thought',
#   'choose',
#   'admired',
#   'could',
#   'can',
#   'know',
#   'rather',
#   'believe',
#   'have',
#   'hope',
#   'think',
#   'have',
#   'wish',
#   'had',
#   'dont',
#   'was',
#   'will',
#   'can',
#   'believe',
#   'used',
#   'found',
#   'wasnt',
#   'was',
#   'told',
#   'watched',
#   'can',
#   'do',
#   'expect',
#   'here',
#   'know',
#   'know',
#   'thought',
#   'know',
#   'know',
#   'don’t',
#   'was',
#   'can’t',
#   'am',
#   'do',
#   'do',
#   'know',
#   'understand',
#   'have',
#   'think',
#   'will',
#   'can',
#   'don’t',
#   'have',
#   'swear',
#   'was',
#   'remember',
#   'did',
#   'had',
#   'knew',
#   'did',
#   'have',
#   'wasnt',
#   'came',
#   'was',
#   'was',
#   'lived',
#   'respect',
#   'will',
#   'will',
#   'choose',
#   'know',
#   'swear',
#   'would',
#   'told',
#   'admire',
#   'still',
#   'have',
#   'have',
#   'tell',
#   'hope',
#   'deserve',
#   'do',
#   'hope',
#   'promise',
#   'did',
#   'did',
#   'had',
#   'suppose',
#   'trust',
#   'told',
#   'do',
#   'worry',
#   'promised',
#   'would',
#   'ever',
#   'beg',
#   'will',
#   'they',
#   'will',
#   'can',
#   'pray',
#   'believe',
#   'ask',
#   'have',
#   'trust',
#   'was',
#   'see',
#   'am',
#   'do',
#   'never',
#   'will',
#   'have',
#   'have',
#   'heard',
#   'am',
#   'am',
#   'will',
#   'keep',
#   'must',
#   'believe',
#   'have',
#   'havent',
#   'am',
#   'wish',
#   'heard',
#   'wondered',
#   'didnt',
#   'doubt',
#   'dont',
#   'used',
#   'was',
#   'saved',
#   'cannot',
#   'feel',
#   'only',
#   'met',
#   'didn’t',
#   'did',
#   'don’t',
#   'believe',
#   'think',
#   'never',
#   'would',
#   'think',
#   'think',
#   'protect',
#   'dont',
#   'thought',
#   'was',
#   'see',
#   'lie',
#   'love',
#   'be'],
#  'have': ['no',
#   'hated',
#   'found',
#   'no',
#   'the',
#   'a',
#   'seen',
#   'seen',
#   'not',
#   'provided',
#   'stopped',
#   'retaken',
#   'one',
#   'suitors',
#   'any',
#   'the',
#   'a',
#   'never',
#   'to',
#   'been',
#   'my',
#   'no',
#   'i',
#   'known',
#   'furthered',
#   'you',
#   'ugly',
#   'left',
#   'been',
#   'been',
#   'her',
#   'always',
#   'you',
#   'youre',
#   'an',
#   'no',
#   'no',
#   'friends',
#   'you',
#   'a',
#   'that',
#   'no',
#   'many',
#   'to',
#   'already',
#   'gotten',
#   'a',
#   'many',
#   'your',
#   'compassion',
#   'a',
#   'gone'],
#  'only': ['whispers',
#   'one',
#   'man',
#   'a',
#   'a',
#   'the',
#   '',
#   'way',
#   'varys',
#   'a',
#   'little',
#   'know'],
#  'whispers': ['before', 'from'],
#  'before': ['all', 'he', 'your', 'your', 'they', 'there'],
#  'all': ['this',
#   'the',
#   'those',
#   'the',
#   'it',
#   'our',
#   'those',
#   'right',
#   'the',
#   'of',
#   'ive',
#   'in',
#   'talk',
#   'then',
#   'but',
#   'you',
#   'rooms',
#   'times',
#   'the',
#   'youd',
#   'of',
#   'the'],
#  'this': ['nastiness',
#   'loss',
#   'is',
#   'country',
#   'city',
#   'its',
#   'strange',
#   'is',
#   'country',
#   'will',
#   'i',
#   'is',
#   'jon',
#   'truly',
#   'far',
#   'time',
#   'time',
#   'is',
#   'country',
#   'kingbeyondthewall',
#   'morning',
#   'city',
#   'way'],
#  'nastiness': ['i'],
#  'was': ['going',
#   'cut',
#   'far',
#   'it',
#   'eager',
#   'born',
#   'cut',
#   'only',
#   'wrongwe',
#   'busy',
#   'an',
#   'neither',
#   'sold',
#   'a',
#   'on',
#   'anointed',
#   'soundly',
#   'sent',
#   'uttered',
#   'never',
#   'able',
#   'a',
#   'a',
#   'we',
#   'best',
#   'littlefinger',
#   'nothing',
#   'truly'],
#  'going': ['to', 'i', 'to', 'to', 'to'],
#  'to': ['tell',
#   'hear',
#   'refuse',
#   'use',
#   'move',
#   'dull',
#   'aid',
#   'die',
#   'live',
#   'spite',
#   'me',
#   'the',
#   'the',
#   'wrap',
#   'them',
#   'pursue',
#   'make',
#   'point',
#   'littlefinger',
#   'merit',
#   'personally',
#   'kings',
#   'the',
#   'fifty',
#   'withstand',
#   'provide',
#   'hear',
#   'our',
#   'such',
#   'sit',
#   'tell',
#   'find',
#   'make',
#   'murder',
#   'find',
#   'the',
#   'this',
#   'drink',
#   'sunup',
#   'beware',
#   'protect',
#   'pentos',
#   'leave',
#   'leave',
#   'listen',
#   'learn',
#   'learn',
#   'my',
#   'find',
#   'make',
#   'see',
#   'see',
#   'you',
#   'kill',
#   'help',
#   'ask',
#   'carry',
#   'decide',
#   'be',
#   'khal',
#   'be',
#   'your',
#   'be',
#   'the',
#   'know',
#   'win',
#   'seeing',
#   'do',
#   'crowds',
#   'settle',
#   'see',
#   'swallow',
#   'say',
#   'admit',
#   'know',
#   'the',
#   'spend',
#   'volantis',
#   'meereen',
#   'keep',
#   'the',
#   'him',
#   'share',
#   'have',
#   'be',
#   'protect',
#   'save',
#   'defeat',
#   'save',
#   'rule',
#   'the',
#   'need',
#   'the',
#   'her',
#   'keep',
#   'live',
#   'make',
#   'be',
#   'her',
#   'call',
#   'people',
#   'this',
#   'have',
#   'pursue',
#   'me',
#   'sansa',
#   'the',
#   'protect',
#   'avenge',
#   'hang',
#   'make',
#   '',
#   'find',
#   'accompany',
#   'the',
#   'come',
#   'go',
#   'do',
#   'kings',
#   'serve',
#   'play',
#   'start',
#   'honor',
#   'hide',
#   'meet',
#   'summon',
#   'see',
#   'westeros',
#   'dorne',
#   'send',
#   'steal',
#   'pick',
#   'do',
#   'be',
#   'kill',
#   'refuse',
#   'play',
#   'come',
#   'horror',
#   'death',
#   'mereen',
#   'tell',
#   'satisfy',
#   'abuse',
#   'kill',
#   'cloak',
#   'make',
#   'know',
#   'listen',
#   'lonely'],
#  'tell': ['you', 'me', 'myself', 'you', 'me', 'you', 'me', 'me', 'i', 'me'],
#  'you': ['the',
#   'want',
#   'can',
#   'do',
#   'want',
#   'have',
#   'say',
#   'can',
#   'know',
#   'to',
#   'are',
#   'trust',
#   'asked',
#   'look',
#   'are',
#   'dont',
#   'believe',
#   'see',
#   'trust',
#   'probably',
#   'have',
#   'how',
#   'are',
#   'need',
#   'bring',
#   'propose',
#   'being',
#   'youll',
#   'someone',
#   'going',
#   'come',
#   'were',
#   'know',
#   'let',
#   'have',
#   'to',
#   'know',
#   'can',
#   'you',
#   'are',
#   'love',
#   'to',
#   'to',
#   'abandoned',
#   'need',
#   'need',
#   'you',
#   'made',
#   'shaved',
#   'look',
#   'really',
#   'climbed',
#   'know',
#   'happy',
#   'are',
#   'try',
#   'and',
#   'pronounce',
#   'but',
#   'did',
#   'start',
#   'need',
#   'and',
#   'can’t',
#   'i',
#   'save',
#   'were',
#   'turned',
#   'wish',
#   'aim',
#   'demand',
#   'let',
#   'well',
#   'on',
#   'because',
#   'i',
#   'think',
#   'martha',
#   'in',
#   'now',
#   'done',
#   'this',
#   'have',
#   'had',
#   'has',
#   'although',
#   'an',
#   'to',
#   'might',
#   'dont',
#   'cant',
#   'a',
#   'were',
#   'know',
#   'and',
#   'know',
#   'think',
#   'i',
#   'in',
#   'were',
#   'came',
#   'your',
#   'came',
#   'have',
#   'know',
#   'think',
#   'considered',
#   'havent',
#   'have',
#   'know',
#   'know',
#   'know',
#   'and',
#   'seem',
#   'spend',
#   'should',
#   'with',
#   'imagine',
#   'with',
#   'ever',
#   'suffered',
#   'tell',
#   'to',
#   'want',
#   '',
#   'ned',
#   'might',
#   'kill',
#   'on',
#   'know',
#   'i',
#   'know',
#   'enjoy',
#   'play',
#   'werent',
#   'begged',
#   'want',
#   'spoke',
#   'hide',
#   'for',
#   'go',
#   'dont',
#   'should',
#   'walk',
#   'walk',
#   'when',
#   'they',
#   'in',
#   'already',
#   'are',
#   'i',
#   'have',
#   'are',
#   'have',
#   'have',
#   'were',
#   'sat',
#   'spread',
#   'won’t',
#   'could',
#   'have',
#   'can',
#   'can',
#   'to',
#   'wouldnt',
#   'remember',
#   'said',
#   'knew',
#   'and',
#   'should',
#   'on',
#   'mind',
#   'this',
#   'any',
#   'but',
#   'fond',
#   'take',
#   'overestimate'],
#  'the': ['story',
#   'free',
#   'man',
#   'while',
#   'flames',
#   'sorcerer',
#   'voice',
#   'flames',
#   'sorcerer',
#   'moment',
#   'sorcerers',
#   'contents',
#   'contents',
#   'slums',
#   'small',
#   'red',
#   'way',
#   'far',
#   'world',
#   'revenge',
#   'stomach',
#   'same',
#   'quiet',
#   'oddest',
#   'lady',
#   'title',
#   'city',
#   'woods',
#   'only',
#   'right',
#   'capital',
#   'first',
#   'army',
#   'truth',
#   'most',
#   'key',
#   'north',
#   'ashes',
#   'bells',
#   'map',
#   'targaryens',
#   'same',
#   'old',
#   'dark',
#   'iron',
#   'only',
#   'traitors',
#   'one',
#   'one',
#   'pitch',
#   'one',
#   'smell',
#   'burning',
#   'thone',
#   'one',
#   'right',
#   'king',
#   'north',
#   'wall',
#   'moment',
#   'capital',
#   'likelihood',
#   'volantene',
#   'fleet',
#   'masters',
#   'whole',
#   'slavers',
#   'drinking',
#   'son',
#   'family',
#   'mysterious',
#   'few',
#   'mind',
#   'will',
#   'right',
#   'capital',
#   'birds',
#   'west',
#   'birds',
#   'east',
#   'mother',
#   'key',
#   'razor',
#   'rest',
#   'way',
#   'company',
#   'most',
#   'city',
#   'room',
#   'wrong',
#   'right',
#   'sons',
#   'harpy',
#   'unsullied',
#   'second',
#   'only',
#   'language',
#   'ladies',
#   'queen’s',
#   'penalty',
#   'boat',
#   'sons',
#   'harpy',
#   'good',
#   'wise',
#   'dogs',
#   'night',
#   'seven',
#   'lord',
#   'headmans',
#   'mad',
#   'kind',
#   'realm',
#   'people',
#   'people',
#   'people',
#   'iron',
#   'people',
#   'mother',
#   'iron',
#   'lord',
#   'visions',
#   'flames',
#   'kitchen',
#   'northern',
#   'gods',
#   'world',
#   'right',
#   'iron',
#   'shadows',
#   'hands',
#   'fiery',
#   'dread',
#   'lysa',
#   'good',
#   'realm',
#   'lie',
#   'last',
#   'masters',
#   'sons',
#   'harpy',
#   'free',
#   'best',
#   'city',
#   'brink',
#   'hero',
#   'chosen',
#   'man',
#   'whole',
#   'lord’s',
#   'lord',
#   'priestess',
#   'man',
#   'entire',
#   'futility',
#   'road',
#   'box',
#   'golden',
#   'greyjoy',
#   'balance',
#   'day',
#   'iron',
#   'new',
#   'better',
#   'throne',
#   'fact',
#   'north',
#   'throne',
#   'eye',
#   'unsullied',
#   'dothraki',
#   'red',
#   'people',
#   'city',
#   'problem',
#   'problem',
#   'best',
#   'lords',
#   'heir',
#   'throne',
#   'one',
#   'north',
#   'seven',
#   'realm',
#   'wrong',
#   'personal',
#   'riverlands',
#   'hound',
#   'phrase',
#   'king',
#   'east',
#   'city',
#   'second',
#   'kingsguard',
#   'unsullied',
#   'absence',
#   'news',
#   'northern',
#   'sea',
#   'next',
#   'victory',
#   'stark',
#   'northerners',
#   'capital',
#   'city',
#   'results',
#   'storms',
#   'big',
#   'little',
#   'queen',
#   'wildlings',
#   'peasants',
#   'gold',
#   'circumstances',
#   'great',
#   'mud',
#   'north',
#   'multitudes',
#   'game',
#   'game',
#   'lord',
#   'summer',
#   'way',
#   'red',
#   'king',
#   'north',
#   'lion',
#   'rest',
#   'sand',
#   'greyjoys',
#   'unsullied',
#   'paving',
#   'sons',
#   'harpy',
#   'sons',
#   'harpy',
#   'fighting',
#   'home',
#   'disaster',
#   'realm',
#   'targaryen',
#   'chain',
#   'narrow',
#   'future',
#   'kingslayer',
#   'seven',
#   'war',
#   'powerful',
#   'powerless',
#   'iron',
#   'land',
#   'seven',
#   'high',
#   'people',
#   'right',
#   'world',
#   'city',
#   'gold',
#   'hands',
#   'king',
#   'histories',
#   'funeral',
#   'queen',
#   'grand',
#   'small',
#   'sellsword',
#   'other',
#   'gods',
#   'power',
#   'executioner',
#   'wall',
#   'karstarks',
#   'young'],
#  'story': ['of', 'people'],
#  'of': ['how',
#   'actors',
#   'that',
#   'the',
#   'his',
#   'the',
#   'sorts',
#   'patience',
#   'his',
#   'my',
#   'a',
#   'his',
#   'myr',
#   'the',
#   'places',
#   'income',
#   'the',
#   'course',
#   'his',
#   'mine',
#   'the',
#   'the',
#   'nothing',
#   'information',
#   'their',
#   'the',
#   'years',
#   'you',
#   'saying',
#   'meereen',
#   'slaver’s',
#   'this',
#   'tywin',
#   'those',
#   'the',
#   'dragons',
#   'your',
#   'the',
#   'the',
#   'the',
#   'course',
#   'silver',
#   'our',
#   'the',
#   'astapor',
#   'yunkai',
#   'course',
#   'westeros',
#   'dragons',
#   'light',
#   'course',
#   'us',
#   'aegons',
#   'balerion',
#   'chairs',
#   'the',
#   'the',
#   'civil',
#   'your',
#   'being',
#   'the',
#   'everything',
#   'talent',
#   'the',
#   'dorne',
#   'people',
#   'mind',
#   'thousands',
#   'innocents',
#   'my',
#   'jon',
#   'westeros',
#   'people',
#   'whom',
#   'us',
#   'our',
#   'unsullied',
#   'sellswords',
#   'us',
#   'desire',
#   'robb',
#   'time',
#   'lying',
#   'your',
#   'life',
#   'me',
#   'honor',
#   'westeros',
#   'light',
#   'jon',
#   'power',
#   'our',
#   'the',
#   'the',
#   'men',
#   'my',
#   'people',
#   'mistakes',
#   'our',
#   'talent',
#   'them',
#   'luck',
#   'wine',
#   'them',
#   'profitable',
#   'his',
#   'the',
#   'your',
#   'his',
#   'his',
#   'harrenhal',
#   'winterfell',
#   'riddles',
#   'course',
#   'an'],
#  'how': ['i',
#   'do',
#   'long',
#   'i',
#   'do',
#   'many',
#   'to',
#   'to',
#   'you',
#   'i',
#   'you',
#   'will',
#   'her',
#   'many',
#   'many',
#   'many',
#   'long',
#   'can',
#   'unspeakable',
#   'do',
#   'he',
#   'the'],
#  'cut': ['do', 'one', 'your', 'in'],
#  'do': ['you',
#   'not',
#   'to',
#   'you',
#   'you',
#   'you',
#   'not',
#   'they',
#   'i',
#   'how',
#   'you',
#   'that',
#   'it',
#   'and',
#   'you',
#   'men',
#   'in',
#   'i',
#   'we',
#   'people',
#   'do',
#   'you',
#   'not',
#   'not',
#   'you',
#   'my',
#   'you',
#   'is',
#   'you',
#   'we',
#   'what',
#   'it',
#   'not',
#   'we'],
#  'want': ['to', 'will', 'to', 'her', 'to', 'to', 'to'],
#  'hear': ['it', 'though'],
#  'it': ['still',
#   'a',
#   'but',
#   'is',
#   'takes',
#   'im',
#   '',
#   '',
#   '',
#   'he',
#   'won’t',
#   'so',
#   'does',
#   'by',
#   'vala',
#   '',
#   'far',
#   'my',
#   'didnt',
#   '',
#   'all',
#   'has',
#   'you',
#   'matters',
#   'hes',
#   'would',
#   'besides',
#   'almost',
#   'seems',
#   'well',
#   'the',
#   'overboard',
#   'for',
#   'for',
#   'for',
#   'would',
#   'where',
#   'werent',
#   'varies',
#   'seems',
#   'he',
#   'resides'],
#  'still': ['as', 'dream', 'neither', 'time', 'dont', 'a'],
#  'as': ['a',
#   'id',
#   'the',
#   'do',
#   'i',
#   'cruel',
#   'the',
#   'long',
#   'i',
#   'a',
#   'an',
#   'the',
#   'hand',
#   'well',
#   'she',
#   'you',
#   'real',
#   'you',
#   'honestly',
#   'i',
#   'its',
#   'for',
#   'hand',
#   'hand',
#   'though',
#   'well',
#   'he'],
#  'boy': ['i', 'in', 'those', 'is', 'mhysa'],
#  'traveled': ['with'],
#  'with': ['a',
#   'a',
#   'her',
#   'him',
#   'no',
#   'such',
#   'a',
#   'his',
#   'the',
#   'them',
#   'no',
#   'the',
#   'these',
#   'the',
#   'fanatics',
#   'a',
#   'his',
#   'help',
#   'blind',
#   'any',
#   'the',
#   'the',
#   'large',
#   'drogon',
#   'two',
#   'her',
#   'have',
#   'the',
#   'sixteen',
#   'a',
#   'a',
#   'me',
#   'the'],
#  'troupe': ['of'],
#  'actors': ['through'],
#  'through': ['the', 'the', 'mutual'],
#  'free': ['cities', 'men', 'to'],
#  'cities': ['one', 'outside'],
#  'one': ['day',
#   'distasteful',
#   'of',
#   'who',
#   'of',
#   'day',
#   'burning',
#   'doing',
#   'doing',
#   'doing',
#   'your',
#   'name',
#   'of',
#   'of',
#   'knows',
#   'of',
#   'by',
#   'of',
#   'man',
#   'is',
#   'free',
#   'weeps',
#   'disputes',
#   'taste',
#   'of'],
#  'day': ['in', 'i', 'i', 'yara', 'power'],
#  'myr': ['a', 'to', 'you'],
#  'certain': ['man', 'hopes', 'about', 'appeal', 'defeat'],
#  'man': ['made',
#   'meant',
#   'with',
#   'in',
#   'who',
#   'can',
#   'living',
#   'named',
#   'standing',
#   'who',
#   'of',
#   'which',
#   'cocks',
#   'alive',
#   'of',
#   'the',
#   'can',
#   '',
#   'but',
#   'im',
#   'between',
#   'bids',
#   'can'],
#  'made': ['my', 'me', 'my', 'brighter', 'a', 'him', 'brighter'],
#  'my': ['master',
#   'senses',
#   'parts',
#   'body',
#   'way',
#   'old',
#   'lady',
#   'allies',
#   'enemies',
#   'lord',
#   'little',
#   'lord',
#   'lady',
#   'heart’s',
#   'dear',
#   'job',
#   'perspective',
#   'queen',
#   'eyes',
#   'true',
#   'queen',
#   'friend',
#   'primary',
#   'life',
#   'reasons',
#   'loyalty',
#   'lord',
#   'birds',
#   'lord',
#   'queen',
#   'lord',
#   'accent',
#   'lord',
#   'lord',
#   'ear',
#   'lord',
#   'lord',
#   'good',
#   'dear',
#   'lord',
#   'lord',
#   'lord',
#   'lord',
#   'lord',
#   'lord',
#   'saying',
#   'lady',
#   'little',
#   'colleague',
#   'lord',
#   'friend',
#   'friend',
#   'dear',
#   'lord',
#   'lord',
#   'lord',
#   'lord',
#   'lord'],
#  'master': ['an'],
#  'an': ['offer',
#   'excellent',
#   'interest',
#   'interest',
#   'audience',
#   'improvement',
#   'offering',
#   'honest',
#   'army',
#   'ear',
#   'idle',
#   'important',
#   'even',
#   'unpleasant'],
#  'offer': ['too'],
#  'too': ['tempting', 'kind', 'many', 'heavy', 'had', 'strong', 'if'],
#  'tempting': ['to'],
#  'refuse': ['i', 'the'],
#  'feared': ['the'],
#  'meant': ['to'],
#  'use': ['me', 'them'],
#  'me': ['as',
#   'a',
#   'powerless',
#   'root',
#   'out',
#   'i',
#   'for',
#   'that',
#   'that',
#   'and',
#   'the',
#   'you’ve',
#   'the',
#   'or',
#   'but',
#   'live',
#   'my',
#   'last',
#   'are',
#   'who',
#   'the',
#   'lord',
#   'when',
#   'then',
#   'live',
#   'of',
#   'no',
#   'only',
#   'to',
#   'i',
#   'to',
#   'to',
#   'if',
#   'if',
#   'i',
#   'my'],
#  'id': ['heard', 'tell'],
#  'heard': ['some', 'a', 'things', 'what', 'he’d', 'you', 'their', 'a'],
#  'some': ['men', 'things', 'solid', '', 'time'],
#  'men': ['used',
#   'in',
#   'decide',
#   'so',
#   'honorable',
#   'but',
#   'in',
#   'of',
#   '',
#   'sit',
#   'believe',
#   'of'],
#  'used': ['small', 'to', 'to', 'to', 'to'],
#  'small': ['boys', 'council', 'council', 'man'],
#  'boys': ['but'],
#  'but': ['what',
#   'the',
#   'you',
#   'influence',
#   'i',
#   'he',
#   'i',
#   'that',
#   'well',
#   'you',
#   'they’re',
#   'between',
#   'birds',
#   'with',
#   'if',
#   'im',
#   'what',
#   'what',
#   'showed',
#   'jon',
#   'if',
#   'theyre',
#   'i',
#   'rest',
#   'i',
#   'they',
#   'even',
#   'when',
#   'not',
#   'earning',
#   'you',
#   'gentler',
#   'everyone',
#   'not',
#   'love',
#   'we',
#   'how',
#   'should',
#   'if',
#   'love'],
#  'what': ['he',
#   'parts',
#   'did',
#   'did',
#   'did',
#   'makes',
#   'youre',
#   'you',
#   'those',
#   'i',
#   'i',
#   'people',
#   'you’ve',
#   'had',
#   'have',
#   'shes',
#   'they',
#   'they',
#   'i',
#   'have',
#   'i',
#   'do',
#   'now',
#   'we',
#   'happens',
#   'he',
#   'you',
#   'desire',
#   'its',
#   'is',
#   'do',
#   'they',
#   'it’s',
#   'was'],
#  'he': ['wanted',
#   'gave',
#   'sliced',
#   'burned',
#   'threw',
#   'very',
#   'do',
#   'be',
#   'goes',
#   'has',
#   'has',
#   'would',
#   'could',
#   'used',
#   'has',
#   'has',
#   'has',
#   'simply',
#   'too',
#   'attacked',
#   'has',
#   'wants',
#   'appears',
#   'took',
#   'said',
#   'didnt',
#   'finds',
#   'fights',
#   'burns',
#   'arrives',
#   'and',
#   'was',
#   'thinks',
#   'grew',
#   'fights',
#   'has'],
#  'wanted': ['was', 'to', 'the', 'the'],
#  'far': ['worse', 'side', 'from', 'from', 'too', 'a'],
#  'worse': ['he', 'and', 'than', 'not'],
#  'gave': ['me'],
#  'potion': ['that'],
#  'that': ['made',
#   'night',
#   'day',
#   'the',
#   'comes',
#   'all',
#   'when',
#   'it',
#   'is',
#   'stannis',
#   'yes',
#   'your',
#   'doesnt',
#   'a',
#   'doesn’t',
#   'i',
#   'makes',
#   'you',
#   'is',
#   'i',
#   'is',
#   'crime',
#   'storm',
#   'you',
#   'is',
#   'a',
#   'the',
#   'would',
#   'he',
#   'is',
#   'she',
#   'throne',
#   'your',
#   'many',
#   'my',
#   '',
#   '“fucking',
#   'has',
#   'takes',
#   'seat',
#   'my',
#   'without',
#   'begin',
#   'the'],
#  'powerless': ['to', 'perhaps'],
#  'move': ['or'],
#  'or': ['speak',
#   'lys',
#   'myr',
#   'face',
#   'queen',
#   'your',
#   'not',
#   'whores',
#   'three',
#   'captured',
#   'captured',
#   'you',
#   'force',
#   'your',
#   'something'],
#  'speak': ['yet', 'the', 'directly', 'more'],
#  'yet': ['did', 'i', 'it', 'no'],
#  'did': ['nothing',
#   'he',
#   'they',
#   'littlefinger',
#   'you',
#   'conspire',
#   'i',
#   'what',
#   'it',
#   'what',
#   'for',
#   'you',
#   'you',
#   'fly',
#   'it'],
#  'nothing': ['to',
#   'worse',
#   'good',
#   'about',
#   'i',
#   'less',
#   'well',
#   'not',
#   'is',
#   'dangerous',
#   'but',
#   'lasts'],
#  'dull': ['my'],
#  'senses': ['with'],
#  'hooked': ['blade'],
#  'blade': ['he', 'i'],
#  'sliced': ['me'],
#  'root': ['and'],
#  'and': ['stem',
#   'i',
#   'a',
#   'ever',
#   'all',
#   'his',
#   'soon',
#   'what',
#   'the',
#   'my',
#   'this',
#   'to',
#   'in',
#   'yet',
#   'heard',
#   'paved',
#   'tonight',
#   'the',
#   'she',
#   'is',
#   'whores',
#   'yunkai',
#   'you',
#   'i',
#   'silver',
#   'strategies',
#   'deceit',
#   'we',
#   'it',
#   'what',
#   'you’ve',
#   'the',
#   'dom',
#   'with',
#   'her',
#   'dom',
#   'the',
#   'that',
#   'carved',
#   'prosper',
#   'why',
#   'nothing',
#   'the',
#   'queens',
#   'seen',
#   'then',
#   'how',
#   'was',
#   'this',
#   'you',
#   'that',
#   'they',
#   'we',
#   'yet',
#   'me',
#   'the',
#   'speak',
#   'the',
#   'the',
#   'measured',
#   'hes',
#   'a',
#   'i',
#   'rules',
#   'barristan',
#   'she',
#   'a',
#   'just',
#   'sister',
#   'got',
#   'on',
#   'go',
#   'i',
#   'started',
#   'if',
#   'ned',
#   'those',
#   'you',
#   'then',
#   'dornish',
#   'the',
#   'not',
#   'throw',
#   'i',
#   'thus',
#   'you',
#   'perhaps',
#   'take',
#   'inspire',
#   'the',
#   'drink',
#   'decide',
#   'blood',
#   'i',
#   'unlike',
#   'sees',
#   'most',
#   'it',
#   'a',
#   'a',
#   'daenerys'],
#  'stem': ['chanting'],
#  'chanting': ['all'],
#  'while': ['he', 'their', 'theres', 'he'],
#  'burned': ['my', 'astapor'],
#  'parts': ['in', 'of'],
#  'brazier': ['the'],
#  'flames': ['turned', 'was', 'that'],
#  'turned': ['blue', 'to'],
#  'blue': ['and'],
#  'voice': ['answer', 'from', 'answered'],
#  'answer': ['his'],
#  'his': ['call',
#   'blade',
#   'red',
#   'house',
#   'purse',
#   'enduring',
#   'girls',
#   'daughter',
#   'armies',
#   'path',
#   'son',
#   'fathers',
#   'mother',
#   'breathing',
#   'support',
#   'aunt',
#   'dismissal',
#   'marriage',
#   'stead',
#   'stead',
#   'enemies',
#   'very',
#   'command',
#   'bannermen',
#   'grandfather',
#   'way',
#   'head'],
#  'call': ['i', 'me'],
#  'dream': ['of', 'of'],
#  'night': ['not', 'gamble', 'cersei'],
#  'not': ['of',
#   'of',
#   'possess',
#   'help',
#   'the',
#   'long',
#   'entirely',
#   'things',
#   'i',
#   'burn',
#   'the',
#   'the',
#   'the',
#   'to',
#   'sure',
#   'make',
#   'we',
#   'bought',
#   'asking',
#   'your',
#   'a',
#   'be',
#   'with',
#   'they',
#   'for',
#   'a',
#   'sure',
#   'like',
#   'destroy',
#   'become',
#   'actually',
#   'at',
#   'me',
#   'how',
#   'even',
#   'sure',
#   'come',
#   'better',
#   'a',
#   'one',
#   'prey',
#   'like',
#   'as',
#   'forget',
#   'in'],
#  'sorcerer': ['not', 'called'],
#  'from': ['the',
#   'the',
#   'the',
#   'asshai',
#   'sundown',
#   'here',
#   'here',
#   'your',
#   'my',
#   'yours',
#   'your',
#   'their',
#   'nothing',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'qarth',
#   'people',
#   'someone',
#   'itself',
#   'cloak'],
#  'god': ['a'],
#  'demon': ['a'],
#  'conjurers': ['trick'],
#  'trick': ['i', 'a'],
#  'dont': ['know',
#   'believe',
#   'entirely',
#   'believe',
#   'know',
#   'like',
#   'pretend',
#   'know',
#   'have',
#   'you',
#   'mind',
#   'think',
#   'abuse',
#   'want',
#   'remind'],
#  'know': ['but',
#   'prodigies',
#   'him',
#   'that',
#   'he',
#   'how',
#   'you',
#   'its',
#   'would',
#   'if',
#   'i',
#   'how',
#   'who',
#   'the',
#   'where',
#   'the',
#   'what',
#   'it',
#   'how',
#   'any',
#   'at',
#   'well',
#   'now',
#   'soon',
#   'our',
#   'them',
#   'its',
#   'where',
#   'i',
#   'their',
#   'there',
#   'jon',
#   'were',
#   'what',
#   'that',
#   'i',
#   'our'],
#  'called': ['and'],
#  'answered': ['and'],
#  'ever': ['since', 'told', 'wanted', 'thought', 'known', 'so'],
#  'since': ['that', 'we', 'our', 'theon'],
#  'hated': ['magic', 'the'],
#  'magic': ['and'],
#  'those': ['who', 'you', 'ships', 'steps', 'big', 'who', 'steps', 'who'],
#  'who': ['practice',
#   'is',
#   'has',
#   'can',
#   'inspires',
#   'could',
#   'could',
#   'you',
#   'funds',
#   'suffer',
#   'wanted',
#   'of',
#   'doesnt',
#   'counseled',
#   'brings',
#   'do',
#   'doesnt',
#   'might',
#   'whisper',
#   'could',
#   'threatened',
#   'despise',
#   'played',
#   'tasted',
#   'wrote',
#   'saw',
#   'can',
#   'said',
#   'work',
#   'i',
#   'know',
#   'lives',
#   'dies',
#   'rule',
#   'was'],
#  'practice': ['it', 'if'],
#  'can': ['see',
#   'read',
#   'help',
#   'think',
#   'stop',
#   'find',
#   'buy',
#   'make',
#   'be',
#   'behead',
#   'devour',
#   'each',
#   'you',
#   'be',
#   'find',
#   'intimidate',
#   'stay',
#   'ride',
#   'cast'],
#  'see': ['why', 'this', 'and', 'things', 'them', 'their', 'what', 'him', 'a'],
#  'why': ['i',
#   'should',
#   'do',
#   'should',
#   'people',
#   'we',
#   'cersei',
#   'most',
#   'you',
#   '',
#   'nothing',
#   'would',
#   'do',
#   'is'],
#  'eager': ['to'],
#  'aid': ['in', 'the'],
#  'fight': ['against'],
#  'against': ['stannis', 'her', 'the'],
#  'stannis': ['and',
#   'baratheon',
#   'with',
#   'baratheon',
#   'baratheon',
#   'and',
#   'does',
#   'a'],
#  'red': ['priestess', 'keep', 'priestess', 'keep', 'waste'],
#  'priestess': ['a', 'from', 'who'],
#  'symbolic': ['revenge'],
#  'revenge': ['of', 'you'],
#  'sorts': ['you'],
#  'possess': ['at'],
#  'at': ['the',
#   'dawn',
#   'supper',
#   'winterfell',
#   'ruling',
#   'her',
#   'all',
#   'such',
#   'least',
#   'keeping',
#   'all',
#   'being',
#   'ilyrio’s',
#   'you',
#   'dwarf',
#   'a'],
#  'moment': ['but', 'we'],
#  'influence': ['is', 'grows', 'on', 'jon'],
#  'is': ['largely',
#   'he',
#   'that',
#   'important',
#   'she',
#   'not',
#   'the',
#   'one',
#   'the',
#   'that',
#   'good',
#   'afloat',
#   'somehow',
#   'a',
#   'worth',
#   'your',
#   'a',
#   'her',
#   'one',
#   'the',
#   'what',
#   'to',
#   'more',
#   'the',
#   'how',
#   'in',
#   'a',
#   'a',
#   'come',
#   'born',
#   'true',
#   'the',
#   'the',
#   'why',
#   'people',
#   'marrying',
#   'a',
#   'why',
#   'bringing',
#   'under',
#   'rest',
#   'made',
#   'our',
#   'true',
#   'ever',
#   'not',
#   'worth',
#   'sitting',
#   'doing',
#   'a',
#   'that',
#   'how'],
#  'largely': ['a'],
#  'matter': ['of', 'what', 'the', 'of'],
#  'patience': ['i'],
#  'found': ['once', 'the', 'favor', 'his'],
#  'once': ['i', 'served', 'we'],
#  'had': ['served', 'not', 'a', 'no', 'to', 'to', 'a', 'heard', 'made', 'and'],
#  'served': ['the', 'another', 'tyrants'],
#  'sorcerers': ['purpose'],
#  'purpose': ['he'],
#  'threw': ['me'],
#  'out': ['of', 'who', 'for', 'this', 'by'],
#  'house': ['to', 'with', 'hire', 'i'],
#  'die': ['i', 'that', 'if'],
#  'resolved': ['to'],
#  'live': ['to', 'i', 'they', 'if'],
#  'spite': ['him'],
#  'him': ['i',
#   'littlefinger',
#   'better',
#   'but',
#   'good',
#   '',
#   'alive',
#   'and',
#   'for',
#   'this',
#   'a',
#   'wildlings',
#   'more',
#   'shed',
#   'to',
#   'more',
#   'again',
#   '',
#   'you',
#   'lord'],
#  'begged': ['i', 'us'],
#  'sold': ['what', 'as'],
#  'body': ['remained', 'for'],
#  'remained': ['to'],
#  'became': ['an'],
#  'excellent': ['thief'],
#  'thief': ['and'],
#  'soon': ['learned', 'then', '', 'they’ll'],
#  'learned': ['that', 'their'],
#  'contents': ['of', 'of'],
#  'mans': ['letters'],
#  'letters': ['are'],
#  'are': ['more',
#   'too',
#   'wrong',
#   'the',
#   'very',
#   'a',
#   'not',
#   'and',
#   'blameless',
#   'thats',
#   'we',
#   'never',
#   'drawn',
#   'the',
#   'going',
#   'important',
#   'dangerous',
#   'dying',
#   'such',
#   'such',
#   'warranted',
#   'fully',
#   'dead',
#   'talking',
#   'faster',
#   'many',
#   'you',
#   'wasted',
#   'now',
#   'podrick',
#   'many',
#   'trying',
#   'in',
#   'you'],
#  'more': ['valuable',
#   'carefully',
#   'than',
#   'than',
#   'kings',
#   'than',
#   'appealing',
#   'whispers',
#   'softly',
#   'sympathetic'],
#  'valuable': ['than'],
#  'than': ['the',
#   'most',
#   'that',
#   'most',
#   'half',
#   'you',
#   'any',
#   'the',
#   'that',
#   'i',
#   'anticipated',
#   'tommen',
#   'stannis'],
#  'purse': ['step'],
#  'step': ['by', 'one'],
#  'by': ['step',
#   'your',
#   'marriage',
#   'gold',
#   'making',
#   'the',
#   'the',
#   'one',
#   'the',
#   'the',
#   'the',
#   'your',
#   'supporting',
#   'millions'],
#  'distasteful': ['task'],
#  'task': ['after'],
#  'after': ['another', 'we', 'him'],
#  'another': ['i', 'who', 'climb'],
#  'way': ['from',
#   'across',
#   'to',
#   'myself',
#   'that',
#   'from',
#   'if',
#   'theon',
#   'into'],
#  'slums': ['of'],
#  'council': ['chamber', 'meeting', 'grows'],
#  'chamber': ['influence'],
#  'grows': ['like', 'smaller'],
#  'like': ['a',
#   'to',
#   'to',
#   'quite',
#   'it',
#   'you',
#   'to',
#   'flies',
#   'the',
#   'a',
#   'you',
#   'to',
#   'most',
#   'you'],
#  'weed': ['i'],
#  'tended': ['mine'],
#  'mine': ['patiently', 'has'],
#  'patiently': ['until'],
#  'until': ['its', 'you', 'your'],
#  'tendrils': ['reached'],
#  'reached': ['from'],
#  'keep': ['all', 'moving', 'them', 'these', 'the', 'on', 'the', 'us'],
#  'across': ['to', 'the', 'the'],
#  'side': ['of', 'my'],
#  'world': ['where', 'holds', 'is'],
#  'where': ['i', 'my', 'power', 'would', 'my', 'will', 'the', 'before', 'men'],
#  'managed': ['to'],
#  'wrap': ['them'],
#  'them': ['around',
#   'so',
#   'alive',
#   'beg',
#   'out',
#   'but',
#   'from',
#   'your',
#   'i',
#   'repulsive',
#   'away',
#   'into',
#   'both',
#   'any',
#   'i',
#   'youre',
#   'to',
#   'to',
#   'quite',
#   'stands',
#   'of'],
#  'around': ['something'],
#  'something': ['very', 'obvious', 'else'],
#  'very': ['special',
#   'large',
#   'organized',
#   'large',
#   'glad',
#   'good',
#   'carefully',
#   'well',
#   'small',
#   'large'],
#  'special': ['hello'],
#  'hello': ['my'],
#  'old': ['friend', 'powers', 'city', 'friend', 'thing', 'men'],
#  'friend': ['its',
#   'lose',
#   'you',
#   'what',
#   'i’ve',
#   'was',
#   'but',
#   'you',
#   'has',
#   'is'],
#  'been': ['a',
#   'made',
#   'burned',
#   'a',
#   'broken',
#   'few',
#   'my',
#   'carried',
#   'butchered',
#   'defeated',
#   'spotted',
#   'noticed',
#   'a',
#   'all',
#   'relieved'],
#  'long': ['time', 'for', 'before', 'as', 'no', 'story', 'do', 'summer'],
#  'doubt': ['the', 'that'],
#  'yours': ['in', 'because', ''],
#  'if': ['you',
#   'robb',
#   'he',
#   'necessary',
#   'anyone',
#   'you',
#   'one',
#   'only',
#   'you',
#   'i',
#   'we',
#   'you',
#   'you',
#   'a',
#   'i',
#   'we',
#   'you',
#   'the',
#   'they',
#   'stannis',
#   'were',
#   'what',
#   'you',
#   'they',
#   'you',
#   'the',
#   'working',
#   'we',
#   'it',
#   'not',
#   'its'],
#  'stomach': ['for'],
#  'for': ['it',
#   'a',
#   'wasting',
#   'her',
#   'the',
#   'the',
#   'horror',
#   'closer',
#   'battle',
#   'all',
#   'a',
#   'mercy',
#   'the',
#   'thousands',
#   'dung',
#   'builders',
#   'whores',
#   'aid',
#   'it',
#   'money',
#   'a',
#   'that',
#   'pentos',
#   'a',
#   'me',
#   'you',
#   'stannis',
#   'her',
#   'all',
#   'your',
#   'the',
#   'now',
#   'good',
#   'a',
#   'long',
#   'him',
#   'their',
#   'ser',
#   'accents',
#   'spiders',
#   'my',
#   'a',
#   'the',
#   'the',
#   'you',
#   'the',
#   'yourself',
#   'politics',
#   'fire',
#   'that',
#   'lord',
#   'me',
#   'your',
#   'some',
#   'the',
#   'robb'],
#  'large': ['extraordinary', 'city', 'house', 'comfortable', 'shadow'],
#  'extraordinary': ['were'],
#  'were': ['talking',
#   'only',
#   'so',
#   'said',
#   'quite',
#   'making',
#   'already',
#   'just',
#   'going',
#   'good',
#   'like',
#   'attacked',
#   'coming',
#   'your',
#   'perfect'],
#  'talking': ['about', 'about', 'about'],
#  'about': ['the',
#   'this',
#   'to',
#   'her',
#   'you',
#   'to',
#   'yours',
#   'the',
#   'her',
#   'destiny',
#   'it',
#   'the',
#   'leaving',
#   'the',
#   'him',
#   'it'],
#  'same': ['podrick', 'while'],
#  'podrick': ['the', 'is', 'would', 'we'],
#  'quiet': ['boy'],
#  'tyrions': ['service'],
#  'service': ['seems', 'to', 'and'],
#  'seems': ['a', 'such', 'a', 'theyve', 'the'],
#  'bit': ['simple', 'harder', 'of'],
#  'simple': ['what'],
#  'so': ['what',
#   'ah',
#   'the',
#   'much',
#   'happy',
#   'often',
#   'it’s',
#   'lovely',
#   'highly',
#   'sweet',
#   'where',
#   'used',
#   'we'],
#  'they': ['say',
#   'ring',
#   'forget',
#   'know',
#   'tell',
#   'plotted',
#   'joined',
#   'believe',
#   'are',
#   'say',
#   'know',
#   'say',
#   'do',
#   'will',
#   'find',
#   'all',
#   'deserve',
#   'deserve',
#   'suspected',
#   'disdained',
#   'say',
#   'worship',
#   'say',
#   'are',
#   'know',
#   'take',
#   'catch',
#   'catch'],
#  'say': ['huh',
#   'about',
#   'so',
#   'the',
#   'the',
#   'every',
#   'to',
#   'that',
#   'it’s',
#   'a',
#   'he',
#   'is',
#   'i'],
#  'huh': ['prodigies'],
#  'prodigies': ['appear', 'in'],
#  'appear': ['in'],
#  'oddest': ['of'],
#  'places': ['and', 'indeed'],
#  'littlefinger': ['say', 'to', 'could', 'is', 'was', 'is', 'looks'],
#  'loss': ['of'],
#  'income': ['ah'],
#  'ah': ['yes', 'you', 'the'],
#  'yes': ['to', 'the', 'from', 'best', 'but', 'because', 'after'],
#  'pursue': ['his', 'other'],
#  'enduring': ['love'],
#  'love': ['of', 'him', 'not', 'ser', 'conversations', 'telling'],
#  'lady': ['arryn', 'i', 'sansa', 'find', '', 'sansas'],
#  'arryn': ['and', 'of', 'and'],
#  'title': ['that'],
#  'comes': ['with'],
#  'her': ['sad',
#   'wellbeing',
#   'father',
#   'indeed',
#   'father',
#   'listen',
#   'fault',
#   'life',
#   'young',
#   'even',
#   'now',
#   'chambers',
#   'i',
#   'coin',
#   'your',
#   'queens',
#   'authority',
#   'state',
#   'life',
#   'that',
#   'will',
#   'jorah',
#   'as',
#   'and',
#   'back',
#   'she',
#   'your',
#   'to'],
#  'sad': ['really'],
#  'really': ['is', 'do', 'speak', 'going', 'satisfied'],
#  'takes': ['to', 'work'],
#  'make': ['our',
#   'a',
#   'her',
#   'dwarf',
#   'us',
#   'this',
#   'you',
#   'you',
#   'a',
#   'i',
#   'an',
#   'him'],
#  'our': ['friend',
#   'sakes',
#   'door',
#   'mutual',
#   'leatherclad',
#   'side',
#   'pact',
#   'profession',
#   'queen',
#   'soldiers',
#   'plan',
#   'guests',
#   'iron',
#   'captured',
#   'fleet',
#   'remaining',
#   'country',
#   'mutual',
#   'influence'],
#  'lose': ['interest', 'more'],
#  'interest': ['in', 'in', 'in', 'in', 'no'],
#  'poor': ['sansa', 'dom'],
#  'sansa': ['stark', 'stark', 'stark', 'stark', 'is', 'stark'],
#  'stark': ['what',
#   'is',
#   'perhaps',
#   'goes',
#   'falls',
#   'is',
#   'mother',
#   'had',
#   'auxiliary',
#   'was',
#   'were',
#   'and',
#   'youll',
#   'lost'],
#  'makes': ['you', 'perfect', 'him'],
#  'read': ['rare'],
#  'rare': ['for'],
#  'woman': ['in', 'and'],
#  'profession': ['of', 'considering'],
#  'course': ['im', 'i', 'man', 'they', 'she'],
#  'im': ['missing',
#   'not',
#   'sure',
#   'not',
#   'not',
#   'not',
#   'not',
#   'not',
#   'asking',
#   'worried',
#   'quite',
#   'wrong',
#   'sure',
#   'not',
#   'afraid',
#   'not',
#   'afraid',
#   'afraid',
#   'not',
#   'not',
#   'afraid',
#   'afraid'],
#  'missing': ['something', 'you'],
#  'obvious': ['youre', 'perhaps'],
#  'youre': ['about',
#   'not',
#   'suggesting',
#   'worried',
#   'drinking',
#   'quite',
#   'afraid'],
#  'point': ['out', '', 'of'],
#  'important': ['enough', 'that', 'im', 'part'],
#  'enough': ['to'],
#  'merit': ['a'],
#  'featherbed': ['besides'],
#  'besides': ['littlefinger', 'the'],
#  'could': ['he',
#   'not',
#   'be',
#   'spend',
#   'make',
#   'possibly',
#   'have',
#   'help',
#   'too',
#   'help'],
#  'bringing': ['one', 'them'],
#  'girls': ['how', 'either'],
#  'odd': ['places'],
#  'indeed': ['my', 'shed'],
#  'personally': ['welcome'],
#  'welcome': ['you', 'at', 'to'],
#  'kings': ['landing',
#   'landing',
#   'and',
#   'landing',
#   'landing',
#   'are',
#   'landing',
#   'hold'],
#  'landing': ['the', 'howled', 'and', 'courtesy', 'with', 'my'],
#  'city': ['has',
#   'under',
#   'to',
#   'the',
#   'choking',
#   'if',
#   'was',
#   'you',
#   'and',
#   'is',
#   'watch',
#   'faced'],
#  'has': ['been',
#   'sadly',
#   'taken',
#   'told',
#   'acquired',
#   'the',
#   'taken',
#   'kept',
#   'returned',
#   'the',
#   'the',
#   'the',
#   'to',
#   'landed',
#   'a',
#   'never',
#   'taken',
#   'offered',
#   'arrived',
#   'grown',
#   'retaken',
#   'the',
#   'convinced',
#   'as',
#   'a',
#   'been',
#   'taken',
#   'conquered',
#   'a',
#   'two',
#   'three',
#   'been',
#   'promised',
#   'named',
#   'named',
#   'been',
#   'three',
#   'led',
#   'been',
#   'their',
#   'been',
#   'found',
#   'neither'],
#  'brighter': ['by', 'by'],
#  'presence': ['a', 'in', 'we'],
#  'little': ['obvious', 'birds', 'birds', 'fish', 'birds', 'birds'],
#  'perhaps': ['might',
#   'i',
#   'youll',
#   'thats',
#   'its',
#   'you',
#   'his',
#   'and',
#   'we’ve'],
#  'might': ['i', 'accidentally', 'be', 'actually', 'be'],
#  'sit': ['youve', 'on', 'in'],
#  'youve': ['taken', 'been', 'seen', 'always'],
#  'taken': ['an', 'an', 'up', 'from', 'hold', 'up', 'wing'],
#  'she': ['she',
#   'has',
#   'never',
#   'is',
#   'has',
#   'once',
#   'hasnt',
#   'wants',
#   'does',
#   'was',
#   'already',
#   'has',
#   'commands',
#   'has',
#   'has',
#   'has',
#   'already',
#   'has',
#   'did',
#   'does'],
#  'sadly': ['well', 'my'],
#  'well': ['forgive',
#   'suited',
#   'never',
#   'that',
#   'i',
#   'for',
#   'try',
#   'why',
#   'then',
#   'they',
#   'but',
#   'as',
#   'in',
#   'played'],
#  'forgive': ['me', 'me'],
#  'wasting': ['your'],
#  'then': ['i', 'i', 'its', 'what', 'theres', 'monsters', 'there'],
#  'thought': ['we', 'we', 'you', 'about', 'you'],
#  'we': ['shared',
#   'set',
#   'should',
#   'break',
#   'were',
#   'need',
#   'could',
#   'both',
#   'returned',
#   'both',
#   'have',
#   'abandon',
#   'get',
#   'find',
#   'really',
#   'find',
#   'surround',
#   'do',
#   'attack',
#   'are',
#   'dont',
#   'choose',
#   'received',
#   'were',
#   'have',
#   'shouldnt',
#   'dont',
#   'have',
#   'could',
#   'tried',
#   'are',
#   'assume',
#   'had',
#   'wont',
#   'are',
#   'will',
#   'are',
#   'pretend',
#   'dont'],
#  'shared': ['certain'],
#  'hopes': ['for'],
#  'wellbeing': ['i'],
#  'choose': ['my', 'you', 'wisely'],
#  'allies': ['carefully', 'by', 'were'],
#  'carefully': ['and', 'still', 'which'],
#  'enemies': ['more', 'forged', 'alive'],
#  'neither': ['a', 'mad', 'crown'],
#  'babe': ['in'],
#  'woods': ['i'],
#  'admired': ['her'],
#  'father': ['i',
#   '',
#   'to',
#   'and',
#   'hears',
#   'and',
#   'has',
#   'to',
#   'has',
#   'didnt',
#   'has',
#   'or',
#   'paid'],
#  'help': ['lord', 'his', 'you', 'from', 'her', 'another'],
#  'daughter': ['youre'],
#  'shed': ['make', 'bend'],
#  'lovely': ['match', 'bride', 'today', 'creature'],
#  'match': ['for'],
#  'right': ['suitor',
#   'counsel',
#   'last',
#   'answers',
#   'i',
#   'ruler',
#   'everything',
#   'family'],
#  'suitor': ['littlefinger'],
#  'capital': ['a', '', 'endangers', 'friends'],
#  'confidant': ['of'],
#  'told': ['me', 'you', 'myself', 'you', 'you', 'your'],
#  'when': ['he', 'i', 'their', 'did', 'i', 'i', 'all', 'he', 'i', 'ned'],
#  'goes': ['sansa', 'with'],
#  'born': ['with', 'into', 'the', 'and', 'into'],
#  'lands': ['no'],
#  'wealth': ['no', 'but'],
#  'armies': ['he', 'and', 'she'],
#  'acquired': ['the'],
#  'first': ['two'],
#  'two': ['how', 'knights', 'seasoned', 'or', 'who'],
#  'army': ['perhaps', 'of', 'at', 'and'],
#  'youll': ['laugh', 'lose', 'have', 'have', 'be'],
#  'laugh': ['but'],
#  'better': ['than',
#   'place',
#   'chance',
#   'claim',
#   'than',
#   'ruler',
#   'writer',
#   'westeros'],
#  'most': ['and',
#   'dangerous',
#   'famous',
#   'people',
#   'of',
#   'certainly',
#   'of',
#   'highborn',
#   'men',
#   'of'],
#  'truth': ['littlefinger', 'nothing'],
#  'dangerous': ['men', 'and', 'proposition', 'down', 'man'],
#  'westeros': ['if', 'and', 'despise', 'whose', 'thrilling', '', 'needs'],
#  'robb': ['stark', 'starks', 'stark', 'stark'],
#  'falls': ['sansa'],
#  'key': ['to', 'you'],
#  'north': ['which', '', 'you', 'in', 'my', ''],
#  'which': ['seems', 'of', 'is', 'you', 'is', 'makes', 'means', 'would'],
#  'such': ['a', 'a', 'a', 'powers', 'a', 'a', 'exclusive', 'fearsome', 'an'],
#  'shame': ['why', 'you', 'archmaester'],
#  'should': ['a', 'keep', 'not', 'i', 'speak', 'return', 'be', 'i'],
#  'low': ['reputation'],
#  'reputation': ['steal'],
#  'steal': ['away', 'from'],
#  'away': ['such', 'his', 'children', 'and', 'on'],
#  'bride': ['actually'],
#  'actually': ['i', 'a', 'be', 'a'],
#  'rather': ['enjoy'],
#  'enjoy': ['him', 'the'],
#  'would': ['see',
#   'you',
#   'expect',
#   'we',
#   'be',
#   'look',
#   'make',
#   'seem',
#   'let',
#   'you',
#   'like',
#   'be',
#   'i',
#   'you',
#   'seem'],
#  'country': ['burn', 'you', 'a', 'i', 'imp'],
#  'burn': ['if', 'him'],
#  'king': ['of',
#   'a',
#   'in',
#   'robert',
#   'until',
#   'robert',
#   'or',
#   'was',
#   'in',
#   'wont',
#   'a'],
#  'ashes': ['you'],
#  'kind': ['i', 'the'],
#  'believe': ['i',
#   'in',
#   'in',
#   'ive',
#   'you',
#   'that',
#   'in',
#   'the',
#   'extreme',
#   'in',
#   'men',
#   'it'],
#  'possible': ['solution'],
#  'solution': ['ive', 'you'],
#  'ive': ['always', 'ever', 'ever', 'heard', 'served', 'spoken', 'lost'],
#  'bells': ['they'],
#  'ring': ['for'],
#  'horror': ['a', 'we'],
#  'dead': ['king', 'man', 'or', 'or', 'man'],
#  'under': ['siege', 'despots', 'just', 'obligation'],
#  'siege': ['exactly', 'and'],
#  'exactly': ['podrick', 'yes'],
#  'entirely': ['sure', 'trust', 'its'],
#  'sure': ['what', 'many', 'how', 'there', 'you', 'it', 'youd'],
#  'suggesting': ['do'],
#  'trust': ['him', 'have', 'me', 'i', 'me', 'you', ''],
#  'good': ['the',
#   'to',
#   '',
#   'face',
#   'influence',
#   'life',
#   'luck',
#   'masters',
#   'of',
#   'start',
#   'i',
#   'you',
#   'at',
#   'friends',
#   'at',
#   'men',
#   '',
#   'portion'],
#  'map': ['you'],
#  'asked': ['for', 'me'],
#  'closer': ['to'],
#  'fifty': ['the'],
#  'targaryens': ['built'],
#  'built': ['this'],
#  'withstand': ['a'],
#  'provide': ['escape', 'answers'],
#  'escape': ['if'],
#  'necessary': ['that'],
#  'though': ['im', 'it', 'a', 'i’m', 'the'],
#  'many': ['captains',
#   'new',
#   'times',
#   'killings',
#   'masters',
#   'others',
#   'of',
#   'books',
#   'little',
#   'years',
#   'things',
#   'admirable',
#   'who'],
#  'captains': ['say'],
#  'their': ['ship',
#   'screams',
#   'hair',
#   'language',
#   'countrymen',
#   'friends',
#   'job',
#   'designs',
#   'friends',
#   'names',
#   'children',
#   'interest',
#   'songs',
#   'attack',
#   'weaknesses'],
#  'ship': ['is', 'leaving'],
#  'afloat': ['you'],
#  'look': ['well', 'lovely', 'you'],
#  'suited': ['for'],
#  'battle': ['my'],
#  'sakes': ['i'],
#  'hope': ['you', 'i', 'im'],
#  'wrong': ['my', 'answers', 'goodbye', 'person'],
#  'birds': ['tell', 'sing', 'sing', 'always', 'tell', 'who', 'in', 'have'],
#  'baratheon': ['has', 'or', 'did', 'was', 'for'],
#  'up': ['with', 'tyrion', 'as', 'in', 'residence', 'your', 'a'],
#  'asshai': ['you'],
#  'powers': ['my', 'to'],
#  'think': ['you',
#   'of',
#   'it’s',
#   'the',
#   'she',
#   'would',
#   'you',
#   'you',
#   'you',
#   'your'],
#  'seen': ['you', 'things', 'in', 'anyone', 'what'],
#  'probably': ['dont'],
#  'things': ['and', 'things', 'you', 'i', 'from', 'you', 'im', 'have', 'my'],
#  'wish': ['i', 'to', 'we'],
#  'dark': ['arts'],
#  'arts': ['have'],
#  'provided': ['lord'],
#  'paved': ['his'],
#  'path': ['to'],
#  'door': ['for'],
#  'on': ['the',
#   'our',
#   'one',
#   'violence',
#   'a',
#   'without',
#   'your',
#   'the',
#   'theyll',
#   'the',
#   'the',
#   'that',
#   'and',
#   'when',
#   'paddling',
#   'the',
#   'a',
#   'route',
#   'a',
#   'the',
#   'the',
#   'a',
#   'them',
#   'your',
#   'the'],
#  'iron': ['throne', 'throne', 'throne', 'throne', 'islands', 'born', 'throne'],
#  'throne': ['i', 'because', '', 'i', 'im', 'she', 'yes', 'we', 'would'],
#  'tonight': ['i'],
#  'stop': ['him'],
#  'alive': ['alongside', '', 'who', 'who', 'to'],
#  'alongside': ['his'],
#  'son': ['', 'of', 'i’ll'],
#  'thats': ['what', 'their', 'the'],
#  'myself': ['about', 'when', 'i', 'to'],
#  'traitors': ['but'],
#  'wasnt': ['the', 'born', 'a'],
#  'burning': ['them', 'flesh'],
#  'purveyor': ['of'],
#  'information': ['', 'is', 'if'],
#  'watched': ['them'],
#  'beg': ['for', 'you'],
#  'mercy': ['im'],
#  'doing': ['it', 'it', 'it', 'quite'],
#  'pitch': ['of'],
#  'screams': ['rose'],
#  'rose': ['higher'],
#  'higher': ['im'],
#  'hair': ['caught'],
#  'caught': ['fire'],
#  'fire': ['and', 'and'],
#  'smell': ['of'],
#  'flesh': ['filled'],
#  'filled': ['the'],
#  'thone': ['room'],
#  'room': ['im', 'you', 'a'],
#  'never': ['will',
#   'be',
#   'be',
#   'hurt',
#   'been',
#   'follow',
#   'really',
#   'betray',
#   'interested',
#   'forget',
#   'said'],
#  'counsel': [''],
#  'need': ['to', 'to', 'to', 'friends', 'ships', 'to', 'and', 'someone', 'for'],
#  'find': ['a', 'one', 'of', 'a', 'the', 'him', 'us', 'them', 'so', 'himself'],
#  'listen': ['', 'they', 'to'],
#  'jon': ['snow', 'snow', 'grew', 'snow', 'arryn', 'snow', 'and'],
#  'snow': ['', 'aside', 'perhaps', 'but'],
#  'sealed': ['scroll'],
#  'scroll': ['for'],
#  'wall': ['has', 'and'],
#  'kept': ['them'],
#  'thousands': ['of', 'of'],
#  'years': ['', 'before', 'ago'],
#  'presumably': [''],
#  'anything': ['you', 'about'],
#  'bring': ['back'],
#  'back': ['will', 'she', 'in', 'your', 'the'],
#  'useless': ['unless'],
#  'unless': ['cersei'],
#  'cersei': ['grants', 'controls', 'has', 'needs', 'is'],
#  'grants': ['us'],
#  'us': ['an',
#   'the',
#   'for',
#   'family',
#   'dear',
#   'they',
#   'all',
#   'they',
#   'repulsive',
#   'all',
#   'has',
#   'arent',
#   'to',
#   'common',
#   'both',
#   'at'],
#  'audience': ['and'],
#  'somehow': ['convinced'],
#  'convinced': ['not', 'her'],
#  'murder': ['us', 'the'],
#  'set': ['foot'],
#  'foot': ['in'],
#  'fair': ['point'],
#  'propose': ['to'],
#  'grace': ['volantis', 'lady', 'i', 'i', 'i', 'do', 'most', 'hes'],
#  'volantis': ['is', 'of', 'talking'],
#  'likelihood': ['of'],
#  'being': ['spotted', 'king', 'a', 'hand'],
#  'spotted': ['here', 'in'],
#  'here': ['increases', 'only', 'the', 'while', 'to', 'to', '', 'things', 'at'],
#  'increases': ['a'],
#  'hundredfold': ['im'],
#  'new': ['ways', 'life', 'life', 'prince', 'friend'],
#  'ways': ['i', 'to'],
#  'saying': ['this', 'i'],
#  'perfectly': ['good'],
#  'face': ['if', 'the', 'cut'],
#  'anyone': ['recognizes', 'since'],
#  'recognizes': ['you'],
#  'volantene': ['masters'],
#  'masters': ['are', 'have', 'of', 'of', 'how', 'have'],
#  'organized': [''],
#  'flies': ['for', 'yes'],
#  'dung': ['shovelers'],
#  'shovelers': [''],
#  'hammers': ['for'],
#  'builders': [''],
#  'tears': ['for'],
#  'whores': ['lest', 'is', 'i'],
#  'lest': ['they'],
#  'forget': ['', 'a', 'come'],
#  'moving': ['thank'],
#  'thank': ['you'],
#  'someone': ['who', 'who', 'my', 'stronger'],
#  'inspires': ['priests'],
#  'priests': ['and'],
#  'worth': ['taking', 'fighting'],
#  'taking': ['seriously'],
#  'seriously': ['wherere'],
#  'wherere': ['you'],
#  'dwarf': ['jokes', 'in', 'jokes'],
#  'jokes': ['so', 'but', 'why'],
#  'fleet': ['it’s', 'the', ''],
#  'it’s': ['been', 'important', 'safe', 'a', 'hard', 'like'],
#  'astapor': ['and', 'and'],
#  'yunkai': ['have', 'with'],
#  'stopped': ['asking', 'killing'],
#  'asking': ['us', 'you', 'you'],
#  'retaken': ['both', 'the'],
#  'both': ['cities', 'know', 'know', 'tell', 'here'],
#  'outside': ['of'],
#  'meereen': ['the', 'i', 'she'],
#  'whole': ['of', 'point'],
#  'slaver’s': ['bay'],
#  'bay': ['has'],
#  'returned': ['to', 'hasnt'],
#  'slavers': ['do'],
#  'aunt': ['by', 'no', 'common'],
#  'marriage': ['when', 'to', 'to'],
#  'strange': ['country', ''],
#  'child': ['youve', 'i', 'with'],
#  'mutual': ['friend', 'friends', 'friend'],
#  'drink': ['from', 'yourself'],
#  'sundown': ['to'],
#  'sunup': ['visit'],
#  'visit': ['three'],
#  'three': ['brothels', 'dragons', 'dragons', 'ships', 'great'],
#  'brothels': ['a'],
#  'gamble': ['away'],
#  'fathers': ['money', 'kitchen'],
#  'money': ['now', 'im'],
#  'now': ['its',
#   'a',
#   'they',
#   'is',
#   'and',
#   'is',
#   'exactly',
#   'hundreds',
#   'kings',
#   'firmly',
#   'podrick'],
#  'just': ['the', 'as', 'rule', 'as', 'now', 'speaking'],
#  'drinking': ['she', 'quite'],
#  'sweet': ['young', 'again'],
#  'young': ['thing', 'son', 'keep'],
#  'thing': ['none', 'yet', 'im', 'my'],
#  'none': ['of'],
#  'fault': ['no'],
#  'expect': ['not', 'nothing'],
#  'break': ['bread'],
#  'bread': ['with'],
#  'doesnt': ['make', 'like', 'want'],
#  'family': ['weve', 'name', 'name'],
#  'weve': ['learned'],
#  'language': ['but', 'such'],
#  'countrymen': ['if'],
#  'let': ['yourself', 'me', 'me'],
#  'yourself': ['believe', 'get', 'across', 'you', 'that', 'to'],
#  'foreign': ['girl', 'beauty'],
#  'girl': ['with', ''],
#  'name': ['could', 'as', 'matters', 'and', 'isn’t', 'the', 'who', 'ooh'],
#  'spend': ['her', 'the', 'much'],
#  'tywin': ['lannister'],
#  'lannister': ['you', 'is'],
#  'matters': ['diamonds', 'what'],
#  'diamonds': ['id', 'a'],
#  'beware': ['carrying'],
#  'carrying': ['so'],
#  'much': ['wealth', 'time'],
#  'protect': ['yourself', 'i', 'me', 'those'],
#  'get': ['on', 'on', 'in'],
#  'ships': ['sail', 'she’ll', 'escaped', 'after'],
#  'sail': ['to'],
#  'pentos': ['or', 'i’ve'],
#  'lys': ['or'],
#  'buy': ['a'],
#  'these': ['diamonds', 'are', 'days', 'last'],
#  'hire': ['servants'],
#  'servants': ['start'],
#  'start': ['a', 'again', 'sounds', 'a'],
#  'mysterious': ['foreign'],
#  'beauty': ['youll'],
#  'suitors': ['lining'],
#  'lining': ['up'],
#  'few': ['people', 'rulers', 'weeks'],
#  'people': ['alive',
#   'deserve',
#   'happy',
#   'do',
#   'the',
#   'who',
#   'whose',
#   'have',
#   'follow',
#   'like',
#   'know',
#   'are',
#   'you',
#   'many',
#   'i',
#   'what',
#   'like',
#   'who',
#   'a'],
#  'place': ['he'],
#  'mind': ['for', 'your', 'my', 'there'],
#  'last': ['name', 'fortnight', 'i', 'few'],
#  'complication': ['i'],
#  'true': ['love', 'home', 'loyalties', '', 'itll', 'talents'],
#  'bought': ['by'],
#  'gold': ['and', 'cloaks', 'masks', 'cloaks', 'nor'],
#  'silver': ['im', 'to', 'stags'],
#  'leave': ['him', 'because', 'you'],
#  'because': ['your', 'that', 'they', 'i', 'i', 'hes', 'we'],
#  'endangers': ['him'],
#  'home': ['my', 'somewhere', 'of', 'your'],
#  'somewhere': ['far'],
#  'theres': ['still', 'the'],
#  'happy': ['together', 'i’d', 'vala', 'that'],
#  'together': ['until'],
#  'abandoned': ['me', 'houses'],
#  'sing': ['in', 'in'],
#  'west': ['the'],
#  'east': ['if', 'my'],
#  'knows': ['how'],
#  'you’ve': ['already', 'done', 'done', 'sacrificed', 'helped'],
#  'already': ['found',
#   'i’ll',
#   'booked',
#   'has',
#   'told',
#   'in',
#   'destroyed',
#   'taken',
#   'drank'],
#  'favor': ['with', 'with'],
#  'mother': ['of', 'and', 'of', 'jons', 'in'],
#  'dragons': ['information', 'can', '', 'no', 'but'],
#  'learn': ['your', 'which'],
#  'enemies’': ['strengths'],
#  'strengths': ['and'],
#  'strategies': ['you'],
#  'friends': ['are',
#   'if',
#   'in',
#   'back',
#   'in',
#   'fail',
#   'across',
#   'are',
#   'how',
#   'a'],
#  'grand': ['old', 'maester'],
#  'choking': ['on'],
#  'violence': ['corruption'],
#  'corruption': ['and'],
#  'deceit': ['who'],
#  'possibly': ['have'],
#  'any': ['experience', 'king', 'food', 'man', 'more', 'fool', 'honors'],
#  'experience': ['managing'],
#  'managing': ['such'],
#  'massive': ['ungainly'],
#  'ungainly': ['beast'],
#  'beast': ['oh'],
#  'pact': ['with', 'with'],
#  'fanatics': ['if'],
#  'shaved': ['your'],
#  'beard': ['with'],
#  'straight': ['razor'],
#  'razor': ['you’d', 'worked'],
#  'you’d': ['say'],
#  'worked': ['that'],
#  'doesn’t': ['mean'],
#  'mean': ['it'],
#  'won’t': ['cut', 'but'],
#  'throat': ['i'],
#  'don’t': ['return', 'really', 'believe'],
#  'return': ['you’ll', 'to', 'singing'],
#  'you’ll': ['know'],
#  'wrongwe': ['need'],
#  'she’ll': ['come'],
#  'heart’s': ['been'],
#  'broken': ['too'],
#  'times': ['already', 'i'],
#  'i’ll': ['walk', 'even'],
#  'walk': ['the', 'like', 'as'],
#  'rest': ['of', 'easy', 'i', 'sunk'],
#  'can’t': ['go', 'rush'],
#  'go': ['off', 'on', 'on', 'the', ''],
#  'off': ['on'],
#  'secret': ['mission', 'anymore'],
#  'mission': ['in'],
#  'company': ['of', 'has', 'of'],
#  'famous': ['dwarf'],
#  'today': ['my'],
#  'dear': ['you', 'you', 'the', 'im'],
#  'climbed': ['all'],
#  'steps': ['without', 'and'],
#  'without': ['breaking', 'his', 'you'],
#  'breaking': ['a'],
#  'sweat': ['i'],
#  'am': ['not', 'very', 'glad', 'very', 'trying'],
#  'torturer': ['though'],
#  'often': ['is'],
#  'deserve': ['and', 'this', 'to', 'food'],
#  'does': ['provide', 'not', 'to', 'attack', 'it', 'respect'],
#  'answers': ['but', 'my', 'do'],
#  'they’re': ['usually'],
#  'usually': ['the'],
#  'job': ['is', 'what'],
#  'making': ['people', 'a'],
#  'i’d': ['like', 'say'],
#  'vala': ['that’s', 'that’s'],
#  'that’s': ['your', 'all'],
#  'isn’t': ['it', 'that'],
#  'done': ['you’ve', 'a', 'to', 'quickly', 'to'],
#  'lot': ['you’ve', 'a'],
#  'sacrificed': ['your'],
#  'cause': ['which', 'sadly'],
#  'helped': ['the'],
#  'sons': ['of', 'i', 'of', 'of', 'she', 'of', 'of'],
#  'harpy': ['murder', 'some', 'and', 'she', 'planned'],
#  'unsullied': ['and', 'and', 'my', 'did', 'will'],
#  'second': ['sons', 'choice', 'sons'],
#  'understand': ['well'],
#  'perfect': ['sense', 'peace'],
#  'sense': ['from'],
#  'perspective': ['i', 'of', 'just', 'this'],
#  'different': ['perspective'],
#  'try': ['to', 'to', 'again'],
#  'dom': ['happy', 'i’m', 'get', 'or…'],
#  'pronounce': ['it'],
#  'i’m': ['afraid', 'afraid'],
#  'afraid': ['i', 'we’ll', 'shes', 'i', 'foreigners', 'why', 'your', 'we'],
#  'handsome': ['boy'],
#  'big': ['brown', 'fish'],
#  'brown': ['eyes'],
#  'eyes': ['good', 'ill'],
#  'luck': ['keeping', 'can'],
#  'keeping': ['the', 'secrets'],
#  'ladies': ['away'],
#  'children': ['are', 'i'],
#  'blameless': ['i'],
#  'hurt': ['them'],
#  'immediate': ['danger'],
#  'danger': ['this'],
#  'swear': ['to', 'it'],
#  'between': ['us', 'them'],
#  'conspire': ['to'],
#  'kill': ['the', 'a', 'yourself', 'you', 'the'],
#  'queen’s': ['soldiers'],
#  'soldiers': ['we', 'i'],
#  'penalty': ['for'],
#  'crime': ['how'],
#  'breathing': ['problem'],
#  'problem': ['yes', 'there', 'her', 'of'],
#  'third': ['option'],
#  'option': ['though'],
#  'leaving': ['tomorrow', 'you'],
#  'tomorrow': ['for'],
#  'i’ve': ['already', 'brought'],
#  'booked': ['passage'],
#  'passage': ['for'],
#  'even': ['throw', 'before', 'thankfully', 'if', 'longer', 'the', 'if'],
#  'throw': ['in', 'it'],
#  'bag': ['of'],
#  'again': ['though', 'at', 'this', '', ''],
#  'we’ll': ['have'],
#  'ask': ['one', 'why'],
#  'leatherclad': ['friends'],
#  'carry': ['it'],
#  'heavy': ['for'],
#  'boat': ['sails'],
#  'sails': ['at'],
#  'dawn': ['you'],
#  'decide': ['now', 'where', 'if'],
#  'or…': ['sorry'],
#  'sorry': ['i'],
#  'busy': ['learning'],
#  'learning': ['who'],
#  'funds': ['the'],
#  'rush': ['the'],
#  'wise': ['masters'],
#  'fickle': ['but'],
#  'remember': ['that', 'me', 'all'],
#  'storm': ['all'],
#  'dogs': ['in'],
#  'howled': ['through'],
#  'controls': ['fewer'],
#  'fewer': ['than'],
#  'half': ['the', 'your'],
#  'seven': ['kingdoms', 'kingdoms', 'kingdoms', 'kingdoms'],
#  'kingdoms': ['the', 'youve', 'i', 'need'],
#  'despise': ['her', 'you'],
#  'arrival': ['they'],
#  'plotted': ['against'],
#  'joined': ['our'],
#  'queen': ['because',
#   'but',
#   'i',
#   'better',
#   'she',
#   'some',
#   'waiting',
#   'mustnt'],
#  'choice': ['your', 'thwarting', 'to', 'my'],
#  'graceserve': ['robert'],
#  'robert': ['baratheon', 'was', 'was', 'your', 'baratheon'],
#  'headmans': ['axe'],
#  'axe': ['robert'],
#  'improvement': ['on'],
#  'rulers': ['in'],
#  'history': ['as'],
#  'cruel': ['as', 'he'],
#  'mad': ['king', 'nor'],
#  'nor': ['cruel', 'gold', 'favor'],
#  'simply': ['had'],
#  'khal': ['drogo'],
#  'drogo': ['your'],
#  'knew': ['nothing', 'who'],
#  'save': ['your', 'do', 'us'],
#  'existence': ['and'],
#  'said': ['to', 'perhaps', 'you', 'anything', 'you'],
#  'beautiful': ['which'],
#  'advantage': ['king'],
#  'realm': ['needs', 'but', 'millions', 'by'],
#  'needs': ['incompetence', 'to', 'to'],
#  'incompetence': ['should'],
#  'rewarded': ['with'],
#  'blind': ['loyalty', 'allegiance'],
#  'loyalty': ['as', 'stands'],
#  'ill': ['use'],
#  'into': ['a', 'the', 'power', 'a'],
#  'great': ['house', 'promise', 'sieges', 'men', 'man', 'offense'],
#  'came': ['from', 'here', 'to'],
#  'slave': ['and'],
#  'carved': ['up'],
#  'offering': ['when'],
#  'lived': ['in'],
#  'alleys': ['gutters'],
#  'gutters': ['abandoned'],
#  'houses': ['you'],
#  'loyalties': ['lie'],
#  'lie': ['not', 'chaos', 'about'],
#  'suffer': ['under'],
#  'despots': ['and'],
#  'prosper': ['under'],
#  'rule': ['the', 'dont', 'why'],
#  'whose': ['hearts', 'support'],
#  'hearts': ['you'],
#  'aim': ['to'],
#  'win': ['if'],
#  'demand': ['blind'],
#  'allegiance': ['i'],
#  'respect': ['your', 'is'],
#  'wishes': ['grey'],
#  'grey': ['worm'],
#  'worm': ['can'],
#  'behead': ['me'],
#  'devour': ['me'],
#  'serve': ['you', 'as', 'as'],
#  'dedicate': ['myself'],
#  'seeing': ['you', 'each'],
#  'chance': ['than'],
#  'less': ['from', 'wild'],
#  'didnt': ['end', 'seem', 'want', 'take'],
#  'light': ['singled', 'in'],
#  'singled': ['out'],
#  'aside': ['from'],
#  'visions': ['youve'],
#  'supper': ['who'],
#  'martha': [''],
#  'theyll': ['be'],
#  'kitchen': ['the', 'it'],
#  'northern': ['armies', 'cause'],
#  'hasnt': ['seen', 'left', 'accepted'],
#  'left': ['her', 'once'],
#  'chambers': ['hasnt'],
#  'accepted': ['any'],
#  'food': ['youre', 'you', 'for'],
#  'worried': ['for', 'for', 'janos'],
#  'admire': ['your'],
#  'empathy': ['im'],
#  'every': ['time', 'day'],
#  'targaryen': ['is', 'father', 'lives', 'restoration', 'and'],
#  'gods': ['toss', 'but'],
#  'toss': ['a'],
#  'coin': ['and', 'has'],
#  'holds': ['its', 'harrenhal'],
#  'breath': ['we', 'of'],
#  'shes': ['about', 'losing', 'his', 'too'],
#  'power': ['resides', 'were', 'but', 'is', 'when', 'resides'],
#  'resides': ['whether', 'where', 'its'],
#  'whether': ['or'],
#  'ruler': ['on', 'you', 'have', 'might', 'loved'],
#  'landed': ['but'],
#  'quite': ['certain',
#   'the',
#   'good',
#   'a',
#   'knowledgeable',
#   'good',
#   'handsomely',
#   'well'],
#  'known': ['more', 'my', 'your'],
#  'queens': ['than', 'name'],
#  'living': ['ive'],
#  'crowds': ['and'],
#  'shadows': ['i'],
#  'furthered': ['their'],
#  'designs': ['however'],
#  'however': ['horrible'],
#  'horrible': ['but'],
#  'truly': ['i', 'responsible'],
#  'goodbye': ['old'],
#  'quickly': ['trust'],
#  'brought': ['you'],
#  'thousand': ['blades'],
#  'blades': ['taken'],
#  'hands': ['of', 'of'],
#  'aegons': ['fallen'],
#  'fallen': ['enemies'],
#  'forged': ['in'],
#  'fiery': ['breath'],
#  'balerion': ['the'],
#  'dread': ['ha'],
#  'ha': ['im'],
#  'ugly': ['old'],
#  'appeal': ['the'],
#  'lysa': ['arryn'],
#  'chairs': ['shame'],
#  'settle': ['for'],
#  'thwarting': ['you'],
#  'primary': ['ambition'],
#  'ambition': ['i'],
#  'promise': ['you', 'in'],
#  'although': ['who'],
#  'fail': ['now'],
#  'abandon': ['the'],
#  'chaos': ['a'],
#  'gaping': ['pit'],
#  'pit': ['waiting'],
#  'waiting': ['to', 'trouble'],
#  'swallow': ['us'],
#  'fortnight': ['since'],
#  'killings': ['have'],
#  'carried': ['out'],
#  'butchered': ['by'],
#  'safe': ['to', 'here'],
#  'fragile': ['peace'],
#  'peace': ['has', 'prosperity'],
#  'hold': ['for', 'all'],
#  'best': ['we', 'be', 'ruler', 'for'],
#  'considering': ['the'],
#  'brink': ['of'],
#  'civil': ['war'],
#  'war': ['i’d', 'hero', 'to'],
#  'sounds': ['like'],
#  'hero': ['where', ''],
#  'named': ['stannis', 'lord', 'lord'],
#  'anointed': ['as'],
#  'chosen': ['one'],
#  'priestesses': ['he'],
#  'glorious': ['destiny'],
#  'destiny': ['he', 'perhaps'],
#  'attacked': ['king’s', 'on'],
#  'king’s': ['landing'],
#  'soundly': ['defeated'],
#  'defeated': ['by', 'again'],
#  'standing': ['beside'],
#  'beside': ['me'],
#  'he’d': ['been'],
#  'winterfell': ['and', 'is', 'i', 'he'],
#  'suppose': ['it’s'],
#  'hard': ['for'],
#  'fanatic': ['to', 'you’re'],
#  'admit': ['a'],
#  'mistake': ['isn’t', 'this', '', 'you'],
#  'you’re': ['always'],
#  'everything': ['is', 'the'],
#  'lord’s': ['will'],
#  'honest': ['servant'],
#  'servant': ['of'],
#  'counseled': ['stannis'],
#  'double': ['what'],
#  'careful': ['you'],
#  'accidentally': ['consume'],
#  'consume': ['some'],
#  'solid': ['food'],
#  'cant': ['cersei'],
#  'offered': ['a'],
#  'lordship': ['to'],
#  'brings': ['her'],
#  'head': ['are', 'wound', 'who'],
#  'entire': ['road'],
#  'road': ['to', 'to'],
#  'futility': ['of'],
#  'ruling': ['during'],
#  'during': ['your'],
#  'brief': ['tenure'],
#  'tenure': ['as'],
#  'hand': ['still', 'prince', 'in', 'in', 'commander', 'you', 'but'],
#  'talent': ['yes', 'have'],
#  'showed': ['great'],
#  'other': ['areas', 'things', 'and', 'way', 'i', 'for', 'two'],
#  'areas': ['as'],
#  'follow': ['leaders', 'us'],
#  'leaders': ['and'],
#  'repulsive': ['and', 'which'],
#  'surround': ['ourselves'],
#  'ourselves': ['with'],
#  'comfortable': ['boxes'],
#  'boxes': ['to'],
#  'satisfied': ['inside'],
#  'inside': ['the'],
#  'box': ['not'],
#  'golden': ['company'],
#  'arrived': ['in'],
#  'courtesy': ['of'],
#  'greyjoy': ['fleet', 'has', 'captured', 'forgive'],
#  'balance': ['has'],
#  'grown': ['distressingly', 'and', 'so'],
#  'distressingly': ['even'],
#  'thankfully': ['shes'],
#  'losing': ['allies'],
#  'yara': ['greyjoy'],
#  'islands': ['in'],
#  'prince': ['of', 'oberyn'],
#  'dorne': ['pledges', ''],
#  'pledges': ['his'],
#  'support': ['how', 'we'],
#  'others': ['know'],
#  'anymore': ['its'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(varys_dict)
# Out:
# 'Grey worm can read rare for your second sons of income ah yes from the.'
